# %% [markdown]
# ##  Индекс
#
# Сам по себе индекс - это просто формат хранения данных, он не может осуществлять поиск. Для этого необходимо добавить к нему определенную метрику. Это может быть что-то простое типа булева поиска, а может быть что-то более специфическое или кастомное под задачу.
#
# Давайте посмотрим, что полезного можно вытащить из самого индекса.
# По сути, индекс - это информация о частоте встречаемости слова в каждом документе.
# Из этого можно понять, например:
# 1. какое слово является самым часто употребимым / редким
# 2. какие слова встречаются всегда вместе - так можно парсить твиттер, fb, форумы и отлавливать новые устойчивые выражения в речи
# 3. как эти документы кластеризуются по N тематикам согласно словам, которые в них упоминаются

# %% [markdown]
# ## __Задача__:
#
# **Data:** Коллекция субтитров сезонов Друзьей. Одна серия - один документ.
#
# **To do:** Постройте небольшой модуль поискового движка, который сможет осуществлять поиск по коллекции документов.
# На входе запрос и проиндексированная коллекция (в том виде, как посчитаете нужным), на выходе отсортированный по релевантности с запросом список документов коллекции.
#
# Релизуйте:
#     - функцию препроцессинга данных
#     - функцию индексирования данных
#     - функцию метрики релевантности
#     - собственно, функцию поиска
#
# [download_friends_corpus](https://yadi.sk/d/yVO1QV98CDibpw)

# %% [markdown]
# Напоминание про defaultdict:
# > В качестве multiple values словаря рекомендую использовать ``` collections.defaultdict ```
# > Так можно избежать конструкции ``` dict.setdefault(key, default=None) ```

# %%
### _check : в коллекции должно быть около 165 файлов

# %% [markdown]
# С помощью обратного индекса посчитайте:
#
#
# a) какое слово является самым частотным
#
# b) какое самым редким
#
# c) какой набор слов есть во всех документах коллекции
#
# d) какой сезон был самым популярным у Чендлера? у Моники?
#
# e) кто из главных героев статистически самый популярный?

# %% [markdown]
# # Поехали!

# %% [markdown]
# #### Собираем поисковик:

# %%
import os
import re
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()

#preprocessing
def preproc(t):
    t = re.sub(r'[^\w ]',' ',t)
    t = re.sub(r' +', r' ', t)
    t = t.lower()
    t = t.split(' ')
    forms = []
    for word in t: 
        word = morph.parse(word)[0].normal_form
        forms.append(word)
    forms = ' '.join(forms)
    return forms

# %%
#indexing
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

def corpus():
    corpus = []
    names = []
    abspath = r'C:\Users\kapru\Desktop\infosearch-master\friends'
    for root, dirs, files in os.walk(abspath):
        #print(root)
        for name in files:
            names.append(name)
            with open(root+'\\'+name, 'r', encoding='utf-8') as f:  
                text = f.read() 
            a = preproc(text)
            corpus.append(a)
    global vectorizer
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(corpus)
    df = pd.DataFrame(data=X.toarray(), columns=vectorizer.get_feature_names(), index=names)
    return df

# %%
data = corpus()

# %%
len(data)
# Out:
# 165

# %%
#косинусная близость
from scipy import spatial

def relevance(q, data):
    relevance_dict = {}
    for index, row in data.iterrows():
        dataSetII = row.values
        dataSetII = dataSetII.reshape(1, -1)
        result = 1 - spatial.distance.cosine(q, dataSetII)
        relevance_dict[index] = result
    return relevance_dict

# %%
import math

#search 
def search(data):
    q = input()
    q = preproc(q)
    q = vectorizer.transform([q]).toarray()
    rel_dict = relevance(q, data)
    counter = 1
    for ep in sorted(rel_dict.items(), key=lambda x: x[1], reverse=True):
        if math.isnan(ep[1]) or ep[1] == 0:
            break
        print(f"Result №{counter}: {ep[0]} ({ep[1]})")
        counter += 1
    return 'done'

# %%
search(data)
# Out:
# росс
# Result №1: Friends - 5x01 - The One After Ross Says Rachel.ru.txt (0.16974083664332962)
# Result №2: Friends - 5x20 - The One With The Ride Along.ru.txt (0.16726726921361657)
# Result №3: Friends - 4x24-25 - The One With Ross's Wedding (2).ru.txt (0.1593157533198155)
# Result №4: Friends - 6x21 - The One Where Ross Meets Elizabeth's Dad.ru.txt (0.14438980106573496)
# Result №5: Friends - 3x17 - The One Without The Ski Trip.ru.txt (0.13247484602382664)
# Result №6: Friends - 4x23-24 - The One With Ross's Wedding (1).ru.txt (0.1323111355736455)
# Result №7: Friends - 2x01 - The One With Ross's New Girlfriend.ru.txt (0.12309436920156269)
# Result №8: Friends - 4x15 - The One With All The Rugby.ru.txt (0.12240030443441574)
# Result №9: Friends - 2x01 - The One With Ross's New Girlfriend.DVDRip.ru.txt (0.11108783268286904)
# Result №10: Friends - 4x21 - The One With The Invitations.ru.txt (0.11063367300673754)
# Result №11: Friends - 5x06 - The One With The Yeti.ru.txt (0.11044271940465733)
# Result №12: Friends - 6x13 - The One With Rachel's Sister (1).ru.txt (0.09332024349499646)
# Result №13: Friends - 6x09 - The One Where Ross Got High.ru.txt (0.09276748494550535)
# Result №14: Friends - 5x07 - The One Where Ross Moves In.ru.txt (0.0889243643726253)
# Result №15: Friends - 5x02 - The One With All The Kissing.ru.txt (0.0873170465091041)
# Result №16: Friends - 5x15 - The One With The Girl Who Hits Joey.ru.txt (0.0853045242254229)
# Result №17: Friends - 2x08 - The One With The List.ru.txt (0.0836725722454994)
# Result №18: Friends - 5x11 - The One With All The Resolutions.ru.txt (0.07831103281945351)
# Result №19: Friends - 2x10 - The One With Russ.ru.txt (0.07393475364386182)
# Result №20: Friends - 6x01 - The One After Vegas.ru.txt (0.07357948693631844)
# Result №21: Friends - 6x06 - The One On The Last Night.ru.txt (0.06994855329975658)
# Result №22: Friends - 7x08 - The One Where Chandler Doesn't Like Dogs.ru.txt (0.06460536396288485)
# Result №23: Friends - 3x19 - The One With The Tiny T-Shirt.ru.txt (0.06062610560763604)
# Result №24: Friends - 6x02 - The One Where Ross Hugs Rachel.ru.txt (0.0595779498399478)
# Result №25: Friends - 3x15 - The One Where Ross And Rachel Take A Break (1).ru.txt (0.059390339652215296)
# Result №26: Friends - 5x17 - The One With Rachel's Inadvertent Kiss.ru.txt (0.05710402407201609)
# Result №27: Friends - 7x17 - The One With The Cheap Wedding Dress.ru.txt (0.05674044272772005)
# Result №28: Friends - 1x07 - The One With The Blackout.ru.txt (0.05666391063191545)
# Result №29: Friends - 2x16 - The One Where Joey Moves Out.ru.txt (0.0565233418944221)
# Result №30: Friends - 6x04 - The One Where Joey Loses His Insurance.ru.txt (0.05598787993584886)
# Result №31: Friends - 5x09 - The One With Ross's Sandwich.ru.txt (0.05586507154470144)
# Result №137: Friends - 1x11 - The One With Mrs. Bing.ru.txt (0.013410441545721685)
# Result №138: Friends - 2x24 - The One With Barry And Mindy's Wedding.ru.txt (0.013202542526406846)
# Result №139: Friends - 3x13 - The One Where Monica And Richard Are Just Friends.ru.txt (0.013171584244345835)
# Result №140: Friends - 4x07 - The One Where Chandler Crosses The Line.ru.txt (0.012954280817885744)
# Result №141: Friends - 7x18 - The One With Joey's Award.ru.txt (0.012326671027227287)
# Result №142: Friends - 3x11 - The One Where Chandler Can't Remember Which Sister.ru.txt (0.011246253337339307)
# Result №143: Friends - 3x04 - The One With The Metaphorical Tunnel.ru.txt (0.010627328615640641)
# Result №144: Friends - 2x18 - The One Where Dr. Ramoray Dies.ru.txt (0.007490899403510887)
# Result №145: Friends - 1x09 - The One Where Underdog Gets Away.ru.txt (0.007254380701636642)
# Result №146: Friends - 4x04 - The One With The Ballroom Dancing.ru.txt (0.007010857709969787)
# Result №147: Friends - 2x21 - The One With The Bullies.ru.txt (0.006979028124943332)
# Result №148: Friends - 2x03 - The One Where Heckles Dies.ru.txt (0.006834262666401414)
# Result №149: Friends - 7x24-25 - The One With Chandler And Monica's Wedding (2).ru.txt (0.006719738182597745)
# Result №150: Friends - 7x19 - The One With Ross And Monica's Cousin.ru.txt (0.006708690330180844)
# Result №151: Friends - 2x13 - The One After The Super Bowl (2).ru.txt (0.006658090650814241)
# Result №152: Friends - 1x13 - The One With The Boobies.ru.txt (0.006159242410501475)
# Result №153: Friends - 4x09 - The One Where They're Going To Party!.ru.txt (0.00601460918436969)
# Result №154: Friends - 2x04 - The One With Phoebe's Husband.ru.txt (0.005962106035186321)
# Result №155: Friends - 1x20 - The One With The Evil Orthodontist.ru.txt (0.005850755110615391)
# Result №156: Friends - 7x03 - The One With Phoebe's Cookies.ru.txt (0.005785955898698014)
# Result №157: Friends - 7x16 - The One With The Truth About London.ru.txt (0.005647284563097488)
# Result №158: Friends - 3x18 - The One With The Hypnosis Tape.ru.txt (0.005316066439125078)
# 'done'

# %% [markdown]
# #### a) какое слово является самым частотным

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
russian_stopwords = stopwords.words("russian")

def most_freq(data):
    data = data.transpose()
    data['sum'] = data.sum(axis=1)
    most_freq = data.sort_values(by=['sum'], ascending=False)
    return most_freq
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kapru\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
most_freq(data).head()
# Out:
#       Friends - 1x01 - The One Where Monica Gets A Roommate.ru.txt  \
# ты                                                  100
# не                                                   77
# что                                                  64
# это                                                  63
# быть                                                 44
#
#       Friends - 1x02 - The One With The Sonogram At The End.ru.txt  \
# ты                                                   41
# не                                                   41
# что                                                  32
# это                                                  31
# быть                                                 23
#
#       Friends - 1x03 - The One With The Thumb.ru.txt  \
# ты                                                51
# не                                                43
# что                                               36
# это                                               51
# быть                                              26
#
#       Friends - 1x04 - The One With George Stephanopoulos.ru.txt  \
# ты                                                   51
# не                                                   49
# что                                                  57
# это                                                  31
# быть                                                 28
#
#       Friends - 1x05 - The One With The East German Laundry Detergent.ru.txt  \
# ты                                                   63
# не                                                   50
# что                                                  47
# это                                                  45
# быть                                                 28
#
#       Friends - 1x06 - The One With The Butt.ru.txt  \
# ты                                               62
# не                                               43
# что                                              41
# это                                              47
# быть                                             20
#
#       Friends - 1x07 - The One With The Blackout.ru.txt  \
# ты                                                   49
# не                                                   44
# что                                                  43
# это                                                  42
# быть                                                 18
#
#       Friends - 1x08 - The One Where Nana Dies Twice.ru.txt  \
# ты                                                   42
# не                                                   39
# что                                                  43
# это                                                  25
# быть                                                 19
#
#       Friends - 1x09 - The One Where Underdog Gets Away.ru.txt  \
# ты                                                   68
# не                                                   43
# что                                                  45
# это                                                  24
# быть                                                 24
#
#       Friends - 1x10 - The One With The Monkey.ru.txt  ...  \
# ты                                                 68  ...
# не                                                 52  ...
# что                                                32  ...
# это                                                33  ...
# быть                                               27  ...
#
#       Friends - 7x16 - The One With The Truth About London.ru.txt  \
# ты                                                   72
# не                                                   71
# что                                                  64
# это                                                  48
# быть                                                 37
#
#       Friends - 7x17 - The One With The Cheap Wedding Dress.ru.txt  \
# ты                                                   55
# не                                                   48
# что                                                  47
# это                                                  38
# быть                                                 22
#
#       Friends - 7x18 - The One With Joey's Award.ru.txt  \
# ты                                                   61
# не                                                   71
# что                                                  55
# это                                                  43
# быть                                                 35
#
#       Friends - 7x19 - The One With Ross And Monica's Cousin.ru.txt  \
# ты                                                   57
# не                                                   54
# что                                                  66
# это                                                  32
# быть                                                 23
#
#       Friends - 7x20 - The One With Rachel's Big Kiss.ru.txt  \
# ты                                                   75
# не                                                   65
# что                                                  74
# это                                                  59
# быть                                                 41
#
#       Friends - 7x21 - The One With The Vows.ru.txt  \
# ты                                               61
# не                                               70
# что                                              78
# это                                              43
# быть                                             18
#
#       Friends - 7x22 - The One With Chandler's Dad.ru.txt  \
# ты                                                   58
# не                                                   55
# что                                                  49
# это                                                  33
# быть                                                 21
#
#       Friends - 7x23 - The One With Chandler And Monica's Wedding (1).ru.txt  \
# ты                                                   50
# не                                                   61
# что                                                  66
# это                                                  19
# быть                                                 22
#
#       Friends - 7x24-25 - The One With Chandler And Monica's Wedding (2).ru.txt  \
# ты                                                   77
# не                                                   60
# что                                                  44
# это                                                  34
# быть                                                 23
#
#         sum
# ты    11193
# не     9456
# что    9448
# это    7529
# быть   4768
#
# [5 rows x 166 columns]

# %% [markdown]
# Самое частотное слово - **ТЫ**

# %% [markdown]
# #### b) какое слово является самым редким

# %%
# напишем функцию, которая будет находить слова, которые встретились только один раз
def least_freq(data):
    data = data.transpose()
    data['sum'] = data.sum(axis=1)
    least_freq = data.sort_values(by=['sum'], ascending=False)
    least_freq = data['sum']==1
    least_freq = data[least_freq]
    least_list = least_freq.index.values.tolist()
    result = []
    for l_l in least_list:
        if re.search(r'[0-9A-Za-z]', l_l) is None:
            result.append(l_l)
    return result

# %%
print (least_freq(data))
# Out:
# ['аааа', 'ааааааа', 'аааааау', 'аба', 'абонемент', 'абрикос', 'абсурд', 'абсурдный', 'авансом', 'аварийный', 'авиа', 'авиамодельный', 'авианосец', 'авиапочта', 'аврора', 'австралийский', 'австралия', 'авто', 'автобизнес', 'автобусный', 'автомобиль', 'авторство', 'автостоп', 'агамемнон', 'агрегат', 'ад', 'адвокатский', 'аделаида', 'адидас', 'адно', 'адресат', 'адресовать', 'адский', 'азарт', 'азартный', 'академический', 'акесента', 'аккумулятор', 'аккуратничать', 'акр', 'активно', 'активность', 'акула', 'акустика', 'аланость', 'алгонкин', 'алда', 'алджернон', 'алек', 'алиментный', 'алименты', 'алкоголик', 'алкоголичка', 'алкогольный', 'аллах', 'аллен', 'аллергичный', 'алтеа', 'алый', 'альбайно', 'альвареза', 'альтернатива', 'ама', 'амандочка', 'амбициозный', 'амбиция', 'амери', 'американ', 'американск', 'амстердам', 'амузбушнуть', 'амур', 'амфибия', 'аналитик', 'аналогичный', 'анастассакиснуть', 'анатомировать', 'анатомически', 'анджелес', 'анжел', 'анжелос', 'анжелось', 'аниматор', 'анкета', 'анонимный', 'анонс', 'анти', 'антигистамин', 'антизамужний', 'антиперспирант', 'антихрист', 'антрополог', 'антропология', 'апартамент', 'аперитив', 'аплодировать', 'аплодисменты', 'аппетитный', 'апплодировать', 'аптечка', 'арабский', 'аравийский', 'арбалет', 'арендовать', 'арифметик', 'арка', 'армия', 'аромат', 'ароматерапия', 'артишок', 'артритный', 'артуро', 'аршак', 'арыбахис', 'асбест', 'асидофилус', 'асколт', 'аспарагус', 'аспирантура', 'аспириновый', 'ассорти', 'ассоциироваться', 'астматик', 'астроном', 'ателье', 'атка', 'атлант', 'атом', 'аут', 'афигеть', 'афродизиак', 'афёра', 'аха', 'ача', 'бабища', 'багажник', 'багет', 'багин', 'багс', 'бадминтон', 'базарить', 'бакалейный', 'балаган', 'балдежный', 'балдеть', 'балет', 'балланс', 'баллончик', 'балтика', 'бальзам', 'бамбуковый', 'банальный', 'банановый', 'бандит', 'бандитский', 'баннер', 'банни', 'баннна', 'банный', 'баня', 'бармен', 'барракуда', 'барселона', 'бару', 'барчик', 'барышня', 'баскетболист', 'бассида', 'батарейка', 'баттафуко', 'батхед', 'бах', 'бахрома', 'бдительный', 'бе', 'беарслить', 'бегство', 'бедняга', 'бедовый', 'бедолага', 'бедфорд', 'безалкогольный', 'безвкусно', 'безделушка', 'беззубый', 'безил', 'безличный', 'безногий', 'безопасно', 'безработица', 'безрадостно', 'безрукий', 'безрыбье', 'безумец', 'безумство', 'бейдевинд', 'бейсингер', 'бейтс', 'бекер', 'беккер', 'беленький', 'белоснёжка', 'белочка', 'бельгийски', 'бельгийский', 'бенбрать', 'бени', 'бенитёс', 'беннер', 'бергман', 'берет', 'берк', 'берка', 'берлем', 'берлить', 'берлога', 'бермуды', 'берри', 'берцовый', 'беседовать', 'бесингера', 'бескорыстно', 'бесперспективный', 'бесплодие', 'беспокыться', 'беспощадный', 'беспристрастный', 'бессловный', 'бессмыслица', 'бестактно', 'бетон', 'бешено', 'бешеноглазый', 'би', 'бибикать', 'библейский', 'библиотечный', 'библия', 'бивис', 'биг', 'бигуди', 'биение', 'билдинга', 'билетёр', 'бинокль', 'биологический', 'бионический', 'бирдслить', 'биржевой', 'бирма', 'бирманский', 'бирюлька', 'бисексуал', 'бистро', 'бит', 'бифокальный', 'бишоп', 'благо', 'благовоние', 'благодетельственный', 'благородный', 'благородство', 'благословение', 'благословление', 'блаженный', 'блевания', 'блейра', 'блекджек', 'блеск', 'блеснуть', 'блестючок', 'блеф', 'бли', 'ближневосточный', 'близняшка', 'блик', 'блиман', 'блинчик', 'блондинистый', 'блондиночка', 'блоха', 'блудный', 'блумингдейл', 'блумингдейлз', 'блумингдейлс', 'блумингделс', 'блуминдейл', 'блэк', 'блэкджек', 'блюдце', 'блюз', 'блюзовый', 'блюмиз', 'блюмингсдейлс', 'бля', 'боа', 'бобовый', 'богемный', 'боглый', 'боготворить', 'бодолеар', 'бодрствование', 'бодрствовать', 'бодрячок', 'боевитый', 'боец', 'боковина', 'боком', 'болдуин', 'болевой', 'болезненно', 'болезнина', 'болельщик', 'болонья', 'болт', 'болтовня', 'болш', 'больусиливаться', 'большойский', 'большущий', 'бомбей', 'бомбочка', 'бонсаий', 'бонсай', 'бора', 'боргнайн', 'бордюр', 'бормашина', 'бормотать', 'бортанула', 'босиком', 'бот', 'ботан', 'боуя', 'бошо', 'бравый ...

# %%
print ('Первые 30 редких слов: ', least_freq(data)[:30])
# Out:
# Первые 30 редких слов:  ['аааа', 'ааааааа', 'аааааау', 'аба', 'абонемент', 'абрикос', 'абсурд', 'абсурдный', 'авансом', 'аварийный', 'авиа', 'авиамодельный', 'авианосец', 'авиапочта', 'аврора', 'австралийский', 'австралия', 'авто', 'автобизнес', 'автобусный', 'автомобиль', 'авторство', 'автостоп', 'агамемнон', 'агрегат', 'ад', 'адвокатский', 'аделаида', 'адидас', 'адно']

# %% [markdown]
# #### c) какой набор слов есть во всех документах коллекции

# %%
data
# Out:
#                                                     00  000  007  009  02  \
# Friends - 1x01 - The One Where Monica Gets A Ro...   5    0    0    0   0
# Friends - 1x02 - The One With The Sonogram At T...   5    0    0    0   0
# Friends - 1x03 - The One With The Thumb.ru.txt       5    0    0    0   0
# Friends - 1x04 - The One With George Stephanopo...   5    0    0    0   0
# Friends - 1x05 - The One With The East German L...   5    0    0    0   0
# Friends - 1x06 - The One With The Butt.ru.txt        5    0    0    0   0
# Friends - 1x07 - The One With The Blackout.ru.txt    5    0    0    0   0
# Friends - 1x08 - The One Where Nana Dies Twice....   5    0    0    0   0
# Friends - 1x09 - The One Where Underdog Gets Aw...   5    0    0    0   0
# Friends - 1x10 - The One With The Monkey.ru.txt      5    0    0    0   0
# Friends - 1x11 - The One With Mrs. Bing.ru.txt       5    0    0    0   0
# Friends - 1x12 - The One With The Dozen Lasagna...   6    0    0    0   0
# Friends - 1x13 - The One With The Boobies.ru.txt     5    0    0    0   0
# Friends - 1x14 - The One With The Candy Hearts....   5    0    0    0   0
# Friends - 1x15 - The One With The Stoned Guy.ru...   6    0    0    0   0
# Friends - 1x16 - The One With Two Parts (1).ru.txt   5    0    0    0   0
# Friends - 1x17 - The One With Two Parts (2).ru.txt   5    0    0    0   0
# Friends - 1x18 - The One With All The Poker.ru.txt   5    0    0    0   0
# Friends - 7x09 - The One With All The Candy.ru.txt    0    0      0    0
# Friends - 7x10 - The One With The Holiday Armad...    0    0      0    0
# Friends - 7x11 - The One With All The Cheesecak...    0    0      0    0
# Friends - 7x12 - The One Where They're Up All N...    0    0      0    0
# Friends - 7x13 - The One Where Rosita Dies.ru.txt     0    0      0    0
# Friends - 7x14 - The One Where They All Turn Th...    0    0      0    0
# Friends - 7x15 - The One With Joey's New Brain....    0    0      0    0
# Friends - 7x16 - The One With The Truth About L...    0    0      0    0
# Friends - 7x17 - The One With The Cheap Wedding...    0    0      0    0
# Friends - 7x18 - The One With Joey's Award.ru.txt     0    0      0    0
# Friends - 7x19 - The One With Ross And Monica's...    0    0      0    0
# Friends - 7x20 - The One With Rachel's Big Kiss...    0    0      0    0
# Friends - 7x21 - The One With The Vows.ru.txt         0    0      0    0
# Friends - 7x22 - The One With Chandler's Dad.ru...    0    0      0    0
# Friends - 7x23 - The One With Chandler And Moni...    0    0      0    0
# Friends - 7x24-25 - The One With Chandler And M...    0    0      0    0
#
# [165 rows x 15049 columns]

# %%
def less_freq(data):
    data = data.transpose()
    data['min'] = data.min(axis=1)
    less_freq = data.sort_values(by=['min'], ascending=False)
    return less_freq

# %%
less_freq_data = less_freq(data)

# %%
less_freq_data=less_freq_data[less_freq_data['min']!=0]

# %%
less_freq_data.head()
# Out:
#       Friends - 1x01 - The One Where Monica Gets A Roommate.ru.txt  \
# не                                                   77
# ты                                                  100
# что                                                  64
# это                                                  63
# быть                                                 44
#
#       Friends - 1x02 - The One With The Sonogram At The End.ru.txt  \
# не                                                   41
# ты                                                   41
# что                                                  32
# это                                                  31
# быть                                                 23
#
#       Friends - 1x03 - The One With The Thumb.ru.txt  \
# не                                                43
# ты                                                51
# что                                               36
# это                                               51
# быть                                              26
#
#       Friends - 1x04 - The One With George Stephanopoulos.ru.txt  \
# не                                                   49
# ты                                                   51
# что                                                  57
# это                                                  31
# быть                                                 28
#
#       Friends - 1x05 - The One With The East German Laundry Detergent.ru.txt  \
# не                                                   50
# ты                                                   63
# что                                                  47
# это                                                  45
# быть                                                 28
#
#       Friends - 1x06 - The One With The Butt.ru.txt  \
# не                                               43
# ты                                               62
# что                                              41
# это                                              47
# быть                                             20
#
#       Friends - 1x07 - The One With The Blackout.ru.txt  \
# не                                                   44
# ты                                                   49
# что                                                  43
# это                                                  42
# быть                                                 18
#
#       Friends - 1x08 - The One Where Nana Dies Twice.ru.txt  \
# не                                                   39
# ты                                                   42
# что                                                  43
# это                                                  25
# быть                                                 19
#
#       Friends - 1x09 - The One Where Underdog Gets Away.ru.txt  \
# не                                                   43
# ты                                                   68
# что                                                  45
# это                                                  24
# быть                                                 24
#
#       Friends - 1x10 - The One With The Monkey.ru.txt  ...  \
# не                                                 52  ...
# ты                                                 68  ...
# что                                                32  ...
# это                                                33  ...
# быть                                               27  ...
#
#       Friends - 7x16 - The One With The Truth About London.ru.txt  \
# не                                                   71
# ты                                                   72
# что                                                  64
# это                                                  48
# быть                                                 37
#
#       Friends - 7x17 - The One With The Cheap Wedding Dress.ru.txt  \
# не                                                   48
# ты                                                   55
# что                                                  47
# это                                                  38
# быть                                                 22
#
#       Friends - 7x18 - The One With Joey's Award.ru.txt  \
# не                                                   71
# ты                                                   61
# что                                                  55
# это                                                  43
# быть                                                 35
#
#       Friends - 7x19 - The One With Ross And Monica's Cousin.ru.txt  \
# не                                                   54
# ты                                                   57
# что                                                  66
# это                                                  32
# быть                                                 23
#
#       Friends - 7x20 - The One With Rachel's Big Kiss.ru.txt  \
# не                                                   65
# ты                                                   75
# что                                                  74
# это                                                  59
# быть                                                 41
#
#       Friends - 7x21 - The One With The Vows.ru.txt  \
# не                                               70
# ты                                               61
# что                                              78
# это                                              43
# быть                                             18
#
#       Friends - 7x22 - The One With Chandler's Dad.ru.txt  \
# не                                                   55
# ты                                                   58
# что                                                  49
# это                                                  33
# быть                                                 21
#
#       Friends - 7x23 - The One With Chandler And Monica's Wedding (1).ru.txt  \
# не                                                   61
# ты                                                   50
# что                                                  66
# это                                                  19
# быть                                                 22
#
#       Friends - 7x24-25 - The One With Chandler And Monica's Wedding (2).ru.txt  \
# не                                                   60
# ты                                                   77
# что                                                  44
# это                                                  34
# быть                                                 23
#
#       min
# не     35
# ты     28
# что    27
# это    16
# быть   13
#
# [5 rows x 166 columns]

# %% [markdown]
# #### d) какой сезон был самым популярным у Чендлера? у Моники?

# %%
def find_by_season(q):
    q = preproc(q)
    q = vectorizer.transform([q]).toarray()
    rel_dict = relevance(q, data)

    seasons_dict = {}
    for name, freq in rel_dict.items():
        season = name.split()[2][0]
        if season not in seasons_dict:
            seasons_dict[season] = 0
        seasons_dict[season] += freq

    return seasons_dict

# %%
find_by_season('Чендлер')
# Out:
# {'1': 0.4054513513534349,
#  '2': 0.32907062312099666,
#  '3': 0.4602605590288613,
#  '4': 0.6315973965737751,
#  '5': 0.7850288582713495,
#  '6': 0.7961610624274671,
#  '7': 0.8550839436716484}

# %% [markdown]
# У Чендлера самым популярным был **7 сезон**

# %%
find_by_season('Моника')
# Out:
# {'1': 0.40416182627732655,
#  '2': 0.5297923530494582,
#  '3': 0.4257012794969729,
#  '4': 0.4540689829635567,
#  '5': 0.7848411678191626,
#  '6': 0.736843650840707,
#  '7': 0.9602121445342797}

# %% [markdown]
# У Моники самым популярным был **7 сезон**

# %% [markdown]
# #### e) кто из главных героев статистически самый популярный?

# %%
def freq_by_all_seasons(q):
    q = preproc(q)
    q = vectorizer.transform([q]).toarray()
    rel_dict = relevance(q, data)

    freq_sum = 0
    for freq in rel_dict.values():
        freq_sum += freq
    return freq_sum

def popular_character(data):
    names = ['рэйчел','моника','фиби','джой','чендлер','росс']
    max_freq = 0
    popular = ''
    for name in names:
        freq = freq_by_all_seasons(name)
        if freq > max_freq:
            max_freq = freq
            popular = name
    return popular

# %%
popular_character(data)
# Out:
# C:\Users\kapru\AppData\Roaming\Python\Python37\site-packages\scipy\spatial\distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# 'росс'

# %% [markdown]
# Самый популярный герой - **Росс**
